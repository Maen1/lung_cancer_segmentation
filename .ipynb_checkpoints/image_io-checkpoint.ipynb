# %%
import matplotlib.pyplot as plt
import imageio as imo
import numpy as np
import scipy.ndimage as ndi
import cv2

# %%
im = imo.imread('../datasets/azm/IM-0009-0454.dcm')
#im.meta

# %%
plt.imshow(im, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
path = '../datasets/azm/'

# %%
vol = imo.mvolread(path)
# Out:
# Reading DICOM (examining files): 1/1102 files (0.1%41/1102 files (3.782/1102 files (7.4122/1102 files (11.1151/1102 files (13.7189/1102 files (17.2223/1102 files (20.2264/1102 files (24.0304/1102 files (27.6345/1102 files (31.3385/1102 files (34.9427/1102 files (38.7466/1102 files (42.3504/1102 files (45.7522/1102 files (47.4562/1102 files (51.0600/1102 files (54.4642/1102 files (58.3681/1102 files (61.8722/1102 files (65.5754/1102 files (68.4794/1102 files (72.1835/1102 files (75.8876/1102 files (79.5916/1102 files (83.1956/1102 files (86.8997/1102 files (90.51039/1102 files (94.3%1078/1102 files (97.8  Warn: sampling does not match.
# Reading DICOM (examining files): 1078/1102 files (97.8%1102/1102 files (100.0%)
#   Found 4 correct series.
# Reading DICOM (loading data): 2/2  (100.0%)
# Reading DICOM (loading data): 2/2  (100.0%)
# Reading DICOM (loading data): 11/558  (2.038/558  (6.866/558  (11.8%90/558  (16.1%115/558  (20.6137/558  (24.6148/558  (26.5168/558  (30.1186/558  (33.3213/558  (38.2240/558  (43.0268/558  (48.0295/558  (52.9320/558  (57.3346/558  (62.0372/558  (66.7398/558  (71.3415/558  (74.4444/558  (79.6468/558  (83.9495/558  (88.7523/558  (93.7551/558  (98.7558/558  (100.0%)
# Reading DICOM (loading data): 12/540  (2.239/540  (7.268/540  (12.6%97/540  (18.0%119/540  (22.0146/540  (27.0174/540  (32.2202/540  (37.4226/540  (41.9242/540  (44.8262/540  (48.5289/540  (53.5316/540  (58.5344/540  (63.7372/540  (68.9398/540  (73.7424/540  (78.5448/540  (83.0472/540  (87.4490/540  (90.7517/540  (95.7538/540  (99.6540/540  (100.0%)

# %%
plt.imshow(vol[2][0], cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
fig, axes = plt.subplots(nrows=1,
ncols=3)
axes[0].imshow(vol[0][1],cmap='gray')
axes[1].imshow(vol[1][0],cmap='gray')
axes[2].imshow(vol[2][0],cmap='gray')

for ax in axes:
    ax.axis('off')
    plt.show()

# %%
im = vol[2][59]
hist = ndi.histogram(im, min=0, max=255, bins=256)
plt.plot(hist)

# %%
filt = ndi.gaussian_filter(im, sigma=4)
mask = filt > 350
labels, nlabels = ndi.label(mask)

# %%
fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].imshow(labels, cmap='rainbow')
axes[1].imshow(im)

# %%
plt.imshow(labels)
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
nlabels
# Out:
# 7

# %%
boxes = ndi.find_objects(labels)
boxes[0]
# Out:
# (slice(252L, 269L, None), slice(176L, 197L, None))

# %%
im_bin = ndi.binary_erosion(labels, iterations=2).astype(im.dtype)
plt.imshow(im_bin)

# %%
imo.imwrite('1.png', im_bin)

# %%
img_path = '../datsets/io_images/img/'
msk_path = '../datsets/io_images/msk/'
for i in range(2):
    im= vol[2][i]
    filt = ndi.gaussian_filter(im, sigma=4)
    mask = filt > 350
    labels, nlabels = ndi.label(mask)
    im_bin = ndi.binary_erosion(labels, iterations=2).astype(im.dtype)
    imo.imwrite(img_path+str(i)+'.png', im)
    imo.imwrite(msk_path+str(i)+'.png', im_bin)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-65-2a161d19da1f> in <module>()
#       7     labels, nlabels = ndi.label(mask)
#       8     im_bin = ndi.binary_erosion(labels, iterations=2).astype(im.dtype)
# ----> 9     imo.imwrite(img_path+str(i)+'.png', im)
#      10     imo.imwrite(msk_path+str(i)+'.png', im_bin)
#      11
#
# /Users/Maen/.virtualenvs/tf/lib/python2.7/site-packages/imageio/core/functions.pyc in imwrite(uri, im, format, **kwargs)
#     300
#     301     # Get writer and write first
# --> 302     writer = get_writer(uri, format, "i", **kwargs)
#     303     with writer:
#     304         writer.append_data(im)
#
# /Users/Maen/.virtualenvs/tf/lib/python2.7/site-packages/imageio/core/functions.pyc in get_writer(uri, format, mode, **kwargs)
#     215
#     216     # Create request object
# --> 217     request = Request(uri, "w" + mode, **kwargs)
#     218
#     219     # Get format
#
# /Users/Maen/.virtualenvs/tf/lib/python2.7/site-packages/imageio/core/request.pyc in __init__(self, uri, mode, **kwargs)
#     124
#     125         # Parse what was given
# --> 126         self._parse_uri(uri)
#     127
#     128         # Set extension
#
# /Users/Maen/.virtualenvs/tf/lib/python2.7/site-packages/imageio/core/request.pyc in _parse_uri(self, uri)
#     281                 dn = os.path.dirname(fn)
#     282                 if not os.path.exists(dn):
# --> 283                     raise FileNotFoundError("The directory %r does not exist" % dn)
#     284
#     285     @property
#
# OSError: The directory '/Users/Maen/code/datsets/io_images/img' does not exist
